# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from collections import Counter
from num2words import num2words

import nltk
import os
import string
import numpy as np
import copy
import pandas as pd
import pickle
import re
import math

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %%
INPUT_FOLDER = "isw_to_text"
INPUT_DATA_FILE = "isw_text.csv"

OUTPUT_FOLDER = "ready_text"
OUTPUT_DATA_FILE = "ready_text.csv"
df=pd.read_csv(f"{INPUT_FOLDER}/{INPUT_DATA_FILE}", sep=";")

# %%
def remove_one_letter_word(data):
    words = word_tokenize(str(data))
    new_text = ""
    for w in words:
        if len(w) > 1:
            new_text = new_text + " " + w
    return new_text

# %%
def convert_lower_case(data):
    return np.char.lower(data)

# %%
def remove_stop_words(data):
    stop_words = set(stopwords.words('english')) 
    stop_stop_words = {"no", "not"}
    stop_words = stop_words - stop_stop_words

    words = word_tokenize(str(data))

    new_text = ""
    for w in words:
        if w not in stop_words and len(w) > 1:
            new_text = new_text + " " + w
    return new_text

# %%
def remove_punctuation(data):
    symbols = "!\"#$%&()*+—./:;<=>?@[\]^_`{|}~\n"
    for i in range(len(symbols)):
        data = np.char.replace(data, symbols[i], ' ')
        data = np.char.replace(data, "  ", " ")
        data = np.char.replace(data, ', ', ' ')
    return data

# %%
def remove_apostrophe(data):
    return np.char.replace(data, "'", "")

# %%
def stemming(data):
    stemmer= PorterStemmer()

    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        new_text = new_text + " " + stemmer.stem(w)
    return new_text

def lemmatizing(data):
    lemmatizer = WordNetLemmatizer()

    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        new_text = new_text + " " + lemmatizer.lemmatize(w)
    return new_text

# %%
def convert_numbers(data):
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        if w.isdigit():
            if int(w)<100000000000:
                w = num2words(w)
            else:
                w = ' '
        new_text = new_text + " " + w
    new_text = np.char.replace(new_text, "−", " ")

    return new_text

# %%
def remove_url_string(data):
    words = word_tokenize(str(data))

    new_text = ""
    for w in words:
        w = re.sub(r'^https?:\/\/.*[\r\n]*', '', str(w), flags=re.MULTILINE)
        w = re.sub(r'^http?:\/\/.*[\r\n]*', '', str(w), flags=re.MULTILINE)

        new_text = new_text + " " + w

    return new_text

# %%
def preprocess(data, word_root_algo="lemm"):
    data = remove_one_letter_word(data)
    data = remove_url_string(data)
    data = convert_lower_case(data) # remove comma seperately
    data = remove_apostrophe(data)
    data = remove_stop_words(data)
    data = convert_numbers(data) 
    data = stemming(data) 
    data = remove_punctuation(data)
    data = convert_numbers(data)
    if word_root_algo == "lemm":
        data = lemmatizing(data) 
    else:
        data = stemming(data)   
    data = remove_punctuation(data)
    data = remove_stop_words(data) 
    return data

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
df['lemm'] = df["main_html_v8"].apply(lambda x: preprocess(x,"lemm"))
df['stemm'] = df["main_html_v8"].apply(lambda x: preprocess(x,"stemm"))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...

# %%
df
# Out:
#            date        short_url  \
# 0    2022-02-24  2022-02-24.html
# 1    2022-02-25  2022-02-25.html
# 2    2022-02-26  2022-02-26.html
# 3    2022-02-27  2022-02-27.html
# 4    2022-02-28  2022-02-28.html
# ..          ...              ...
# 325  2023-01-21  2023-01-21.html
# 326  2023-01-22  2023-01-22.html
# 327  2023-01-23  2023-01-23.html
# 328  2023-01-24  2023-01-24.html
# 329  2023-01-25  2023-01-25.html
#
#                                                  title  \
# 0    Russia-Ukraine Warning Update: Initial Russian...
# 1    Russia-Ukraine Warning Update: Russian Offensi...
# 2    Russia-Ukraine Warning Update: Russian Offensi...
# 3    Russia-Ukraine Warning Update: Russian Offensi...
# 4    Russian Offensive Campaign Assessment, Februar...
# ..                                                 ...
# 325  Russian Offensive Campaign Assessment, January...
# 326   Russian Offensive Campaign Assessment, Januar...
# 327  Russian Offensive Campaign Assessment, January...
# 328  Russian Offensive Campaign Assessment, January...
# 329  Russian Offensive Campaign Assessment, January...
#
#                                             text_title  \
# 0    Russia-Ukraine Warning Update: Initial Russian...
# 1    Russia-Ukraine Warning Update: Russian Offensi...
# 2    Russia-Ukraine Warning Update: Russian Offensi...
# 3    Russia-Ukraine Warning Update: Russian Offensi...
# 4    Russian Offensive Campaign Assessment, Februar...
# ..                                                 ...
# 325  Russian Offensive Campaign Assessment, January...
# 326   Russian Offensive Campaign Assessment, Januar...
# 327  Russian Offensive Campaign Assessment, January...
# 328  Russian Offensive Campaign Assessment, January...
# 329  Russian Offensive Campaign Assessment, January...
#
#                                               full_url  \
# 0    /backgrounder/russia-ukraine-warning-update-in...
# 1    /backgrounder/russia-ukraine-warning-update-ru...
# 2    /backgrounder/russia-ukraine-warning-update-ru...
# 3    /backgrounder/russia-ukraine-warning-update-ru...
# 4    /backgrounder/russian-offensive-campaign-asses...
# ..                                                 ...
# 325  /backgrounder/russian-offensive-campaign-asses...
# 326  /backgrounder/russian-offensive-campaign-asses...
# 327  /backgrounder/russian-offensive-campaign-asses...
# 328  /backgrounder/russian-offensive-campaign-asses...
# 329  /backgrounder/russian-offensive-campaign-asses...
#
#                                              main_html  \
# 0      \nMason Clark, George Barros, and Kateryna S...
# 1     Mason Clark, George Barros, and Kateryna Step...
# 2     Mason Clark, George Barros, and Katya Stepane...
# 3     \nMason Clark, George Barros, and Kateryna St...
# 4      \nMason Clark, George Barros, and Kateryna S...
# ..                                                 ...
# 325    \nKarolina Hird, Grace Mappes, Angela Howard...
# 326   \nRussian Offensive Campaign Assessment, Janu...
# 327   \nRussian Offensive Campaign Assessment, Janu...
# 328    \nKarolina Hird, Riley Bailey, Grace Mappes,...
# 329    \nKarolina Hird, Riley Bailey, Kateryna Step...
#
#                                           main_html_v2  \
# 0    Russian President Vladimir Putin began a large...
# 1    Russian forces entered major Ukrainian cities—...
# 2    \nRussian forces’ main axes of advance in the ...
# 3    \nThe Russian military has likely recognized t...
# 4    The Russian military is reorganizing its milit...
# ..                                                 ...
# 325  .\nThe Ukrainian defense of Bakhmut is likely ...
# 326  .\nISW is publishing an abbreviated campaign u...
# 327  .\nUkrainian intelligence assessed that Russia...
# 328  .\nA coalition of NATO member states reportedl...
# 329  .\n Russian forces may be engaging in limited ...
#
#                                           main_html_v8  \
# 0    Russian President Vladimir Putin began a large...
# 1    Russian forces entered major Ukrainian cities—...
# 2    Russian forces’ main axes of advance in the la...
# 3    The Russian military has likely recognized tha...
# 4    The Russian military is reorganizing its milit...
# ..                                                 ...
# 325  .The Ukrainian defense of Bakhmut is likely a ...
# 326  .ISW is publishing an abbreviated campaign upd...
# 327  .Ukrainian intelligence assessed that Russian ...
# 328  .A coalition of NATO member states reportedly ...
# 329  . Russian forces may be engaging in limited sp...
#
#                                                   lemm  \
# 0     russian presid vladimir putin began large-sca...
# 1     russian forc enter major ukrainian city inclu...
# 2     russian forc main axe advanc last twenty-four...
# 3     russian militari like recogn initi expect lim...
# 4     russian militari reorgan militari effort atte...
# ..                                                 ...
# 325   ukrainian defens bakhmut like strateg sound e...
# 326   isw publish abbrevi campaign updat today janu...
# 327   ukrainian intellig ass russian forc prepar of...
# 328   coalit nato member state reportedli send ukra...
# 329   russian forc may engag limit spoil attack acr...
#
#                                                  stemm
# 0     russian presid vladimir putin began large-sc ...
# 1     russian forc enter major ukrainian citi inclu...
# 2     russian forc main axe advanc last twenty-four...
# 3     russian militari like recogn initi expect lim...
# 4     russian militari reorgan militari effort atte...
# ..                                                 ...
# 325   ukrainian defen bakhmut like strateg sound ef...
# 326   isw publish abbrevi campaign updat today janu...
# 327   ukrainian intellig assess russian forc prepar...
# 328   coalit nato member state reportedli send ukra...
# 329   russian forc may engag limit spoil attack acr...
#
# [330 rows x 10 columns]

# %%
df.to_csv(f"{OUTPUT_FOLDER}/{OUTPUT_DATA_FILE}", sep=";",index = False)

# %%
df = pd.read_csv(f"{OUTPUT_FOLDER}/{OUTPUT_DATA_FILE}", sep=";")

# %%
df
# Out:
#            date        short_url  \
# 0    2022-02-24  2022-02-24.html
# 1    2022-02-25  2022-02-25.html
# 2    2022-02-26  2022-02-26.html
# 3    2022-02-27  2022-02-27.html
# 4    2022-02-28  2022-02-28.html
# ..          ...              ...
# 325  2023-01-21  2023-01-21.html
# 326  2023-01-22  2023-01-22.html
# 327  2023-01-23  2023-01-23.html
# 328  2023-01-24  2023-01-24.html
# 329  2023-01-25  2023-01-25.html
#
#                                                  title  \
# 0    Russia-Ukraine Warning Update: Initial Russian...
# 1    Russia-Ukraine Warning Update: Russian Offensi...
# 2    Russia-Ukraine Warning Update: Russian Offensi...
# 3    Russia-Ukraine Warning Update: Russian Offensi...
# 4    Russian Offensive Campaign Assessment, Februar...
# ..                                                 ...
# 325  Russian Offensive Campaign Assessment, January...
# 326   Russian Offensive Campaign Assessment, Januar...
# 327  Russian Offensive Campaign Assessment, January...
# 328  Russian Offensive Campaign Assessment, January...
# 329  Russian Offensive Campaign Assessment, January...
#
#                                             text_title  \
# 0    Russia-Ukraine Warning Update: Initial Russian...
# 1    Russia-Ukraine Warning Update: Russian Offensi...
# 2    Russia-Ukraine Warning Update: Russian Offensi...
# 3    Russia-Ukraine Warning Update: Russian Offensi...
# 4    Russian Offensive Campaign Assessment, Februar...
# ..                                                 ...
# 325  Russian Offensive Campaign Assessment, January...
# 326   Russian Offensive Campaign Assessment, Januar...
# 327  Russian Offensive Campaign Assessment, January...
# 328  Russian Offensive Campaign Assessment, January...
# 329  Russian Offensive Campaign Assessment, January...
#
#                                               full_url  \
# 0    /backgrounder/russia-ukraine-warning-update-in...
# 1    /backgrounder/russia-ukraine-warning-update-ru...
# 2    /backgrounder/russia-ukraine-warning-update-ru...
# 3    /backgrounder/russia-ukraine-warning-update-ru...
# 4    /backgrounder/russian-offensive-campaign-asses...
# ..                                                 ...
# 325  /backgrounder/russian-offensive-campaign-asses...
# 326  /backgrounder/russian-offensive-campaign-asses...
# 327  /backgrounder/russian-offensive-campaign-asses...
# 328  /backgrounder/russian-offensive-campaign-asses...
# 329  /backgrounder/russian-offensive-campaign-asses...
#
#                                              main_html  \
# 0      \nMason Clark, George Barros, and Kateryna S...
# 1     Mason Clark, George Barros, and Kateryna Step...
# 2     Mason Clark, George Barros, and Katya Stepane...
# 3     \nMason Clark, George Barros, and Kateryna St...
# 4      \nMason Clark, George Barros, and Kateryna S...
# ..                                                 ...
# 325    \nKarolina Hird, Grace Mappes, Angela Howard...
# 326   \nRussian Offensive Campaign Assessment, Janu...
# 327   \nRussian Offensive Campaign Assessment, Janu...
# 328    \nKarolina Hird, Riley Bailey, Grace Mappes,...
# 329    \nKarolina Hird, Riley Bailey, Kateryna Step...
#
#                                           main_html_v2  \
# 0    Russian President Vladimir Putin began a large...
# 1    Russian forces entered major Ukrainian cities—...
# 2    \nRussian forces’ main axes of advance in the ...
# 3    \nThe Russian military has likely recognized t...
# 4    The Russian military is reorganizing its milit...
# ..                                                 ...
# 325  .\nThe Ukrainian defense of Bakhmut is likely ...
# 326  .\nISW is publishing an abbreviated campaign u...
# 327  .\nUkrainian intelligence assessed that Russia...
# 328  .\nA coalition of NATO member states reportedl...
# 329  .\n Russian forces may be engaging in limited ...
#
#                                           main_html_v8  \
# 0    Russian President Vladimir Putin began a large...
# 1    Russian forces entered major Ukrainian cities—...
# 2    Russian forces’ main axes of advance in the la...
# 3    The Russian military has likely recognized tha...
# 4    The Russian military is reorganizing its milit...
# ..                                                 ...
# 325  .The Ukrainian defense of Bakhmut is likely a ...
# 326  .ISW is publishing an abbreviated campaign upd...
# 327  .Ukrainian intelligence assessed that Russian ...
# 328  .A coalition of NATO member states reportedly ...
# 329  . Russian forces may be engaging in limited sp...
#
#                                                   lemm  \
# 0     russian presid vladimir putin began large-sca...
# 1     russian forc enter major ukrainian city inclu...
# 2     russian forc main axe advanc last twenty-four...
# 3     russian militari like recogn initi expect lim...
# 4     russian militari reorgan militari effort atte...
# ..                                                 ...
# 325   ukrainian defens bakhmut like strateg sound e...
# 326   isw publish abbrevi campaign updat today janu...
# 327   ukrainian intellig ass russian forc prepar of...
# 328   coalit nato member state reportedli send ukra...
# 329   russian forc may engag limit spoil attack acr...
#
#                                                  stemm
# 0     russian presid vladimir putin began large-sc ...
# 1     russian forc enter major ukrainian citi inclu...
# 2     russian forc main axe advanc last twenty-four...
# 3     russian militari like recogn initi expect lim...
# 4     russian militari reorgan militari effort atte...
# ..                                                 ...
# 325   ukrainian defen bakhmut like strateg sound ef...
# 326   isw publish abbrevi campaign updat today janu...
# 327   ukrainian intellig assess russian forc prepar...
# 328   coalit nato member state reportedli send ukra...
# 329   russian forc may engag limit spoil attack acr...
#
# [330 rows x 10 columns]

# %%
docs = df["lemm"].values.tolist()

# %%
cv = CountVectorizer(max_df=0.98,min_df=2)
word_count_vector = cv.fit_transform(docs)

word_count_vector.shape
# Out:
# (330, 7384)

# %%
with open("model/count_vectorizer_v1.pkl", "wb") as handle:
    pickle.dump(cv, handle)

# %%
tfidf_transformer=TfidfTransformer(smooth_idf=True, use_idf=True,)
tfidf_transformer.fit(word_count_vector)
# Out:
# TfidfTransformer()

# %%
with open("model/tfidf_transformer_v1.pkl", "wb") as handle:
    pickle.dump(tfidf_transformer, handle)

# %%
df_idf = pd.DataFrame(tfidf_transformer.idf_, index = cv.get_feature_names_out(), columns=["idf_weights"])
#  sort ascending
df_idf.sort_values(by=['idf_weights'])
# Out:
#             idf_weights
# war            1.021375
# staff          1.021375
# luhansk        1.021375
# attack         1.021375
# area           1.021375
# ...                 ...
# grinder        5.703506
# grip           5.703506
# grodno         5.703506
# servicemen     5.703506
# сухопутный     5.703506
#
# [7384 rows x 1 columns]

# %%
tf_idf_vector = tfidf_transformer.transform(word_count_vector)

# %%
tfidf = pickle.load (open("model/tfidf_transformer_v1.pkl", "rb"))
cv = pickle.load(open("model/count_vectorizer_v1.pkl", "rb"))

# %%
# you cam only needs to do this once, this is mapping of index to
feature_names=cv.get_feature_names_out()

# %%
feature_names
# Out:
# array(['000', '03', '10', ..., 'zyuganov', 'коридор', 'сухопутный'],
#       dtype=object)

# %%
def sort_coo(coo_matrix):
    tuples = zip (coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

def extract_topn_from_vector(feature_names, sorted_items, topn=10):


    # use only topn items from vector
    sorted_items = sorted_items[:topn]

    score_vals = []
    feature_vals = []

    # word index and corresponding tf-idf score
    for idx, score in sorted_items:
        # keen track of feature name and its corresponding score
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])

    #create a tuples of feature,score
    #results = zio(feature_vals, score_vals)
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    return results

def conver_doc_to_vector (doc):
    feature_names = cv.get_feature_names_out()
    top_n = 100
    tf_idf_vector=tfidf.transform(cv.transform([doc]))
    
    #sort the tf-idf vectors by descending order of scores
    sorted_items=sort_coo(tf_idf_vector.tocoo())

    keywords=extract_topn_from_vector(feature_names,sorted_items, top_n)
    
    return keywords

# %%
df['keywords'] = df['lemm'].apply(lambda x: conver_doc_to_vector(x))

# %%
df
# Out:
#            date        short_url  \
# 0    2022-02-24  2022-02-24.html
# 1    2022-02-25  2022-02-25.html
# 2    2022-02-26  2022-02-26.html
# 3    2022-02-27  2022-02-27.html
# 4    2022-02-28  2022-02-28.html
# ..          ...              ...
# 325  2023-01-21  2023-01-21.html
# 326  2023-01-22  2023-01-22.html
# 327  2023-01-23  2023-01-23.html
# 328  2023-01-24  2023-01-24.html
# 329  2023-01-25  2023-01-25.html
#
#                                                  title  \
# 0    Russia-Ukraine Warning Update: Initial Russian...
# 1    Russia-Ukraine Warning Update: Russian Offensi...
# 2    Russia-Ukraine Warning Update: Russian Offensi...
# 3    Russia-Ukraine Warning Update: Russian Offensi...
# 4    Russian Offensive Campaign Assessment, Februar...
# ..                                                 ...
# 325  Russian Offensive Campaign Assessment, January...
# 326   Russian Offensive Campaign Assessment, Januar...
# 327  Russian Offensive Campaign Assessment, January...
# 328  Russian Offensive Campaign Assessment, January...
# 329  Russian Offensive Campaign Assessment, January...
#
#                                             text_title  \
# 0    Russia-Ukraine Warning Update: Initial Russian...
# 1    Russia-Ukraine Warning Update: Russian Offensi...
# 2    Russia-Ukraine Warning Update: Russian Offensi...
# 3    Russia-Ukraine Warning Update: Russian Offensi...
# 4    Russian Offensive Campaign Assessment, Februar...
# ..                                                 ...
# 325  Russian Offensive Campaign Assessment, January...
# 326   Russian Offensive Campaign Assessment, Januar...
# 327  Russian Offensive Campaign Assessment, January...
# 328  Russian Offensive Campaign Assessment, January...
# 329  Russian Offensive Campaign Assessment, January...
#
#                                               full_url  \
# 0    /backgrounder/russia-ukraine-warning-update-in...
# 1    /backgrounder/russia-ukraine-warning-update-ru...
# 2    /backgrounder/russia-ukraine-warning-update-ru...
# 3    /backgrounder/russia-ukraine-warning-update-ru...
# 4    /backgrounder/russian-offensive-campaign-asses...
# ..                                                 ...
# 325  /backgrounder/russian-offensive-campaign-asses...
# 326  /backgrounder/russian-offensive-campaign-asses...
# 327  /backgrounder/russian-offensive-campaign-asses...
# 328  /backgrounder/russian-offensive-campaign-asses...
# 329  /backgrounder/russian-offensive-campaign-asses...
#
#                                              main_html  \
# 0      \nMason Clark, George Barros, and Kateryna S...
# 1     Mason Clark, George Barros, and Kateryna Step...
# 2     Mason Clark, George Barros, and Katya Stepane...
# 3     \nMason Clark, George Barros, and Kateryna St...
# 4      \nMason Clark, George Barros, and Kateryna S...
# ..                                                 ...
# 325    \nKarolina Hird, Grace Mappes, Angela Howard...
# 326   \nRussian Offensive Campaign Assessment, Janu...
# 327   \nRussian Offensive Campaign Assessment, Janu...
# 328    \nKarolina Hird, Riley Bailey, Grace Mappes,...
# 329    \nKarolina Hird, Riley Bailey, Kateryna Step...
#
#                                           main_html_v2  \
# 0    Russian President Vladimir Putin began a large...
# 1    Russian forces entered major Ukrainian cities—...
# 2    \nRussian forces’ main axes of advance in the ...
# 3    \nThe Russian military has likely recognized t...
# 4    The Russian military is reorganizing its milit...
# ..                                                 ...
# 325  .\nThe Ukrainian defense of Bakhmut is likely ...
# 326  .\nISW is publishing an abbreviated campaign u...
# 327  .\nUkrainian intelligence assessed that Russia...
# 328  .\nA coalition of NATO member states reportedl...
# 329  .\n Russian forces may be engaging in limited ...
#
#                                           main_html_v8  \
# 0    Russian President Vladimir Putin began a large...
# 1    Russian forces entered major Ukrainian cities—...
# 2    Russian forces’ main axes of advance in the la...
# 3    The Russian military has likely recognized tha...
# 4    The Russian military is reorganizing its milit...
# ..                                                 ...
# 325  .The Ukrainian defense of Bakhmut is likely a ...
# 326  .ISW is publishing an abbreviated campaign upd...
# 327  .Ukrainian intelligence assessed that Russian ...
# 328  .A coalition of NATO member states reportedly ...
# 329  . Russian forces may be engaging in limited sp...
#
#                                                   lemm  \
# 0     russian presid vladimir putin began large-sca...
# 1     russian forc enter major ukrainian city inclu...
# 2     russian forc main axe advanc last twenty-four...
# 3     russian militari like recogn initi expect lim...
# 4     russian militari reorgan militari effort atte...
# ..                                                 ...
# 325   ukrainian defens bakhmut like strateg sound e...
# 326   isw publish abbrevi campaign updat today janu...
# 327   ukrainian intellig ass russian forc prepar of...
# 328   coalit nato member state reportedli send ukra...
# 329   russian forc may engag limit spoil attack acr...
#
#                                                  stemm  \
# 0     russian presid vladimir putin began large-sc ...
# 1     russian forc enter major ukrainian citi inclu...
# 2     russian forc main axe advanc last twenty-four...
# 3     russian militari like recogn initi expect lim...
# 4     russian militari reorgan militari effort atte...
# ..                                                 ...
# 325   ukrainian defen bakhmut like strateg sound ef...
# 326   isw publish abbrevi campaign updat today janu...
# 327   ukrainian intellig assess russian forc prepar...
# 328   coalit nato member state reportedli send ukra...
# 329   russian forc may engag limit spoil attack acr...
#
#                                               keywords
# 0    {'pm': 0.378, 'airport': 0.258, 'kyiv': 0.239,...
# 1    {'februari': 0.345, 'pm': 0.328, 'zero': 0.322...
# 2    {'februari': 0.442, 'kyiv': 0.371, 'twenty': 0...
# 3    {'februari': 0.545, 'seven': 0.292, 'twenty': ...
# 4    {'februari': 0.578, 'eight': 0.299, 'twenty': ...
# ..                                                 ...
# 325  {'januari': 0.508, 'teplinski': 0.225, 'milblo...
# 326  {'prigozhin': 0.608, 'putin': 0.331, 'januari'...
# 327  {'januari': 0.68, 'twenty': 0.279, 'thre': 0.2...
# 328  {'januari': 0.54, 'twenty': 0.194, 'bakhmut': ...
# 329  {'januari': 0.579, 'twenty': 0.213, 'milblogg'...
#
# [330 rows x 11 columns]

# %%
OUTPUT_DATA_FILE2 = "vectorized.csv"
df.to_csv(f"{OUTPUT_FOLDER}/{OUTPUT_DATA_FILE2}", sep=";",index = False)
